# %%
# import necessary librraries
import keras
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# Load the text file
path = keras.utils.get_file('nietzsche.txt', origin= 'https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length: ', len(text))
# Out:
# Corpus length:  600893

# %%
# Vectorizing Sequences of characters
maxlen = 60
step = 3

sentences = []

next_chars = []

for i in range(0, len(text)- maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
    
print("Number of sequences: ", len(sentences))

chars = sorted(list(set(text)))
print('Unique characters: ', len(chars))
char_indices = dict((char, chars.index(char)) for char in chars)

print("Vectorization...")
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] =1
# Out:
# Number of sequences:  200278
# Unique characters:  57
# Vectorization...

# %%
# Single-layer LSTM model for next-character prediction
from keras import layers
model =  keras.models.Sequential()
model.add(layers.LSTM(128, input_shape = (maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation = 'softmax'))

# %%
# Model compilation configuration
optumizer = keras.optimizers.RMSprop(lr = 0.01)
model.compile(loss = 'categorical_crossentropy', optimizer= optumizer)

# %%
# Function to sample the next character given the model's predictions
def sample(preds, temerature = 1.0):
    preds = np.asanyarray(preds).astype('float64')
    preds = np.log(preds)/ temerature
    exp_preds = np.exp(preds)
    preds = exp_preds/np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch',epoch)
    model.fit(x, y, batch_size=128, epochs= 1)
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('\n------Generating with seed : "'+ generated_text + '"')
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('\n----temperature:', temperature)
        sys.stdout.writelines(generated_text)
        
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
            
        preds = model.predict(sampled, verbose=0)[0]
        next_index = sample(preds, temperature)
        next_char = chars[next_index]
        generated_text += next_char
        generated_text = generated_text[1:]
        sys.stdout.write(next_char)
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 75s 373us/step - loss: 1.9610
#
# ------Generating with seed : "here one desires to possess"--he is irritated and impatient "
#
# ----temperature: 0.2
# here one desires to possess"--he is irritated and impatient a
# ----temperature: 0.5
# ere one desires to possess"--he is irritated and impatient an
# ----temperature: 1.0
# re one desires to possess"--he is irritated and impatient and
# ----temperature: 1.2
# e one desires to possess"--he is irritated and impatient and epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 74s 372us/step - loss: 1.6253
#
# ------Generating with seed : "that one has duties only to one's
# equals; that one may act t"
#
# ----temperature: 0.2
# that one has duties only to one's
# equals; that one may act th
# ----temperature: 0.5
# hat one has duties only to one's
# equals; that one may act tha
# ----temperature: 1.0
# at one has duties only to one's
# equals; that one may act that
# ----temperature: 1.2
# t one has duties only to one's
# equals; that one may act that epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 75s 374us/step - loss: 1.5355
#
# ------Generating with seed : " is a theory like that
# of freedom of competition, which take"
#
# ----temperature: 0.2
#  is a theory like that
# of freedom of competition, which take
# ----temperature: 0.5
# is a theory like that
# of freedom of competition, which take o
# ----temperature: 1.0
# s a theory like that
# of freedom of competition, which take of
# ----temperature: 1.2
#  a theory like that
# of freedom of competition, which take of epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 75s 374us/step - loss: 1.4875
#
# ------Generating with seed : "elves--precisely here, we are "men of duty," even we! occasi"
#
# ----temperature: 0.2
# elves--precisely here, we are "men of duty," even we! occasio
# ----temperature: 0.5
# lves--precisely here, we are "men of duty," even we! occasion
# ----temperature: 1.0
# ves--precisely here, we are "men of duty," even we! occasion
# ----temperature: 1.2
# es--precisely here, we are "men of duty," even we! occasion vepoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 75s 377us/step - loss: 1.4581
#
# ------Generating with seed : "son.
#
# 236. i have no doubt that every noble woman will oppos"
#
# ----temperature: 0.2
# son.
#
# 236. i have no doubt that every noble woman will oppose
# ----temperature: 0.5
# on.
#
# 236. i have no doubt that every noble woman will opposed
# ----temperature: 1.0
# n.
#
# 236. i have no doubt that every noble woman will opposed
# ----temperature: 1.2
# .
#
# 236. i have no doubt that every noble woman will opposed nepoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 74s 368us/step - loss: 1.4386
#
# ------Generating with seed : "o not venture to mention
# much greater names, but i have them"
#
# ----temperature: 0.2
# o not venture to mention
# much greater names, but i have thems
# ----temperature: 0.5
#  not venture to mention
# much greater names, but i have themse
# ----temperature: 1.0
# not venture to mention
# much greater names, but i have themsel
# ----temperature: 1.2
# ot venture to mention
# much greater names, but i have themselvepoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 75s 375us/step - loss: 1.4206
#
# ------Generating with seed : "an he feared
# death: he was a petty, abject spirit. they perc"
#
# ----temperature: 0.2
# an he feared
# death: he was a petty, abject spirit. they perce
# ----temperature: 0.5
# n he feared
# death: he was a petty, abject spirit. they percei
# ----temperature: 1.0
#  he feared
# death: he was a petty, abject spirit. they perceiv
# ----temperature: 1.2
# he feared
# death: he was a petty, abject spirit. they perceiviepoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 77s 385us/step - loss: 1.4092
#
# ------Generating with seed : "egation of will possible? how is the
# saint possible?--that s"
#
# ----temperature: 0.2
# egation of will possible? how is the
# saint possible?--that se
# ----temperature: 0.5
# gation of will possible? how is the
# saint possible?--that see
# ----temperature: 1.0
# ation of will possible? how is the
# saint possible?--that seem
# ----temperature: 1.2
# tion of will possible? how is the
# saint possible?--that seemsepoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 76s 379us/step - loss: 1.3966
#
# ------Generating with seed : "to would have
# been impossible.--with regard to philosophical"
#
# ----temperature: 0.2
# to would have
# been impossible.--with regard to philosophical
# ----temperature: 0.5
# o would have
# been impossible.--with regard to philosophical p
# ----temperature: 1.0
#  would have
# been impossible.--with regard to philosophical pe
# ----temperature: 1.2
# would have
# been impossible.--with regard to philosophical perepoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 77s 383us/step - loss: 1.3870
#
# ------Generating with seed : " praise nature and necessity. just as he cherishes the
# beaut"
#
# ----temperature: 0.2
#  praise nature and necessity. just as he cherishes the
# beauti
# ----temperature: 0.5
# praise nature and necessity. just as he cherishes the
# beautif
# ----temperature: 1.0
# raise nature and necessity. just as he cherishes the
# beautifu
# ----temperature: 1.2
# aise nature and necessity. just as he cherishes the
# beautifucepoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 77s 383us/step - loss: 1.3794
#
# ------Generating with seed : "t of the origin of the famous antithesis "good" and
# "evil":-"
#
# ----temperature: 0.2
# t of the origin of the famous antithesis "good" and
# "evil":--
# ----temperature: 0.5
#  of the origin of the famous antithesis "good" and
# "evil":--t
# ----temperature: 1.0
# of the origin of the famous antithesis "good" and
# "evil":--th
# ----temperature: 1.2
# f the origin of the famous antithesis "good" and
# "evil":--thaepoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 77s 384us/step - loss: 1.3729
#
# ------Generating with seed : " more
# intellectual, our tendencies more rational, and our ju"
#
# ----temperature: 0.2
#  more
# intellectual, our tendencies more rational, and our jud
# ----temperature: 0.5
# more
# intellectual, our tendencies more rational, and our judg
# ----temperature: 1.0
# ore
# intellectual, our tendencies more rational, and our judgm
# ----temperature: 1.2
# re
# intellectual, our tendencies more rational, and our judgmeepoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 77s 385us/step - loss: 1.3644
#
# ------Generating with seed : "e goal in itself, as if it were salvation
# and glorification-"
#
# ----temperature: 0.2
# e goal in itself, as if it were salvation
# and glorification--
# ----temperature: 0.5
#  goal in itself, as if it were salvation
# and glorification--a
# ----temperature: 1.0
# goal in itself, as if it were salvation
# and glorification--as
# ----temperature: 1.2
# oal in itself, as if it were salvation
# and glorification--as epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 77s 385us/step - loss: 1.3597
#
# ------Generating with seed : "ordially and thoroughly;--the genius of the heart, which imp"
#
# ----temperature: 0.2
# ordially and thoroughly;--the genius of the heart, which impo
# ----temperature: 0.5
# rdially and thoroughly;--the genius of the heart, which impos
# ----temperature: 1.0
# dially and thoroughly;--the genius of the heart, which imposs
# ----temperature: 1.2
# ially and thoroughly;--the genius of the heart, which impossiepoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 77s 385us/step - loss: 1.3519
#
# ------Generating with seed : "d never have arisen, the
# longing for an ever new widening of"
#
# ----temperature: 0.2
# d never have arisen, the
# longing for an ever new widening of
# ----temperature: 0.5
#  never have arisen, the
# longing for an ever new widening of t
# ----temperature: 1.0
# never have arisen, the
# longing for an ever new widening of th
# ----temperature: 1.2
# ever have arisen, the
# longing for an ever new widening of threpoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 77s 382us/step - loss: 1.3480
#
# ------Generating with seed : "german philosophy depended nevertheless on his pride, and
# on"
#
# ----temperature: 0.2
# german philosophy depended nevertheless on his pride, and
# onl
# ----temperature: 0.5
# erman philosophy depended nevertheless on his pride, and
# only
# ----temperature: 1.0
# rman philosophy depended nevertheless on his pride, and
# only
# ----temperature: 1.2
# man philosophy depended nevertheless on his pride, and
# only pepoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 74s 372us/step - loss: 1.3436
#
# ------Generating with seed : "hy and the "warm heart."--it
# is the powerful who know how to"
#
# ----temperature: 0.2
# hy and the "warm heart."--it
# is the powerful who know how to
# ----temperature: 0.5
# y and the "warm heart."--it
# is the powerful who know how to t
# ----temperature: 1.0
#  and the "warm heart."--it
# is the powerful who know how to th
# ----temperature: 1.2
# and the "warm heart."--it
# is the powerful who know how to thiepoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 76s 377us/step - loss: 1.3387
#
# ------Generating with seed : "satisfaction with its own condition, or an admiration of wha"
#
# ----temperature: 0.2
# satisfaction with its own condition, or an admiration of what
# ----temperature: 0.5
# atisfaction with its own condition, or an admiration of what
# ----temperature: 1.0
# tisfaction with its own condition, or an admiration of what t
# ----temperature: 1.2
# isfaction with its own condition, or an admiration of what thepoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 76s 379us/step - loss: 1.3357
#
# ------Generating with seed : "to what degree life has disgusted them, by the extent to whi"
#
# ----temperature: 0.2
# to what degree life has disgusted them, by the extent to whic
# ----temperature: 0.5
# o what degree life has disgusted them, by the extent to which
# ----temperature: 1.0
#  what degree life has disgusted them, by the extent to which
# ----temperature: 1.2
# what degree life has disgusted them, by the extent to which pepoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 76s 380us/step - loss: 1.3324
#
# ------Generating with seed : "uals, a feeling in common can scarcely arise at
# all, at most"
#
# ----temperature: 0.2
# uals, a feeling in common can scarcely arise at
# all, at most
# ----temperature: 0.5
# als, a feeling in common can scarcely arise at
# all, at most d
# ----temperature: 1.0
# ls, a feeling in common can scarcely arise at
# all, at most de
# ----temperature: 1.2
# s, a feeling in common can scarcely arise at
# all, at most decepoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 77s 383us/step - loss: 1.3278
#
# ------Generating with seed : "of your own good qualities. formerly
# they were your masters:"
#
# ----temperature: 0.2
# of your own good qualities. formerly
# they were your masters:
# ----temperature: 0.5
# f your own good qualities. formerly
# they were your masters: t
# ----temperature: 1.0
#  your own good qualities. formerly
# they were your masters: th
# ----temperature: 1.2
# your own good qualities. formerly
# they were your masters: theepoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 77s 386us/step - loss: 1.3252
#
# ------Generating with seed : " moral philosophers who appear at this time have
# to preach? "
#
# ----temperature: 0.2
#  moral philosophers who appear at this time have
# to preach? t
# ----temperature: 0.5
# moral philosophers who appear at this time have
# to preach? th
# ----temperature: 1.0
# oral philosophers who appear at this time have
# to preach? the
# ----temperature: 1.2
# ral philosophers who appear at this time have
# to preach? the epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 77s 383us/step - loss: 1.3225
#
# ------Generating with seed : "i have no doubt that they also know how to laugh
# thereby in "
#
# ----temperature: 0.2
# i have no doubt that they also know how to laugh
# thereby in t
# ----temperature: 0.5
#  have no doubt that they also know how to laugh
# thereby in th
# ----temperature: 1.0
# have no doubt that they also know how to laugh
# thereby in the
# ----temperature: 1.2
# ave no doubt that they also know how to laugh
# thereby in the epoch 24
# Epoch 1/1
# 200278/200278 [==============================] - 76s 378us/step - loss: 1.3192
#
# ------Generating with seed : "ions of moral value were at first
# applied to men; and were o"
#
# ----temperature: 0.2
# ions of moral value were at first
# applied to men; and were on
# ----temperature: 0.5
# ons of moral value were at first
# applied to men; and were one
# ----temperature: 1.0
# ns of moral value were at first
# applied to men; and were one
# ----temperature: 1.2
# s of moral value were at first
# applied to men; and were one wepoch 25
# Epoch 1/1
# 200278/200278 [==============================] - 74s 372us/step - loss: 1.3172
#
# ------Generating with seed : "t hearts, he would not easily find therein
# the intention to "
#
# ----temperature: 0.2
# t hearts, he would not easily find therein
# the intention to t
# ----temperature: 0.5
#  hearts, he would not easily find therein
# the intention to th
# ----temperature: 1.0
# hearts, he would not easily find therein
# the intention to the
# ----temperature: 1.2
# earts, he would not easily find therein
# the intention to the epoch 26
# Epoch 1/1
# 200278/200278 [==============================] - 74s 367us/step - loss: 1.3152
#
# ------Generating with seed : "t spiritual expression of a certain many-sided physiological"
#
# ----temperature: 0.2
# t spiritual expression of a certain many-sided physiological
# ----temperature: 0.5
#  spiritual expression of a certain many-sided physiological b
# ----temperature: 1.0
# spiritual expression of a certain many-sided physiological bu
# ----temperature: 1.2
# piritual expression of a certain many-sided physiological bulepoch 27
# Epoch 1/1
# 200278/200278 [==============================] - 73s 365us/step - loss: 1.3108
#
# ------Generating with seed : "t on
# his surface and film whatever "personality" he still po"
#
# ----temperature: 0.2
# t on
# his surface and film whatever "personality" he still pos
# ----temperature: 0.5
#  on
# his surface and film whatever "personality" he still posi
# ----temperature: 1.0
# on
# his surface and film whatever "personality" he still posit
# ----temperature: 1.2
# n
# his surface and film whatever "personality" he still positiepoch 28
# Epoch 1/1
# 200278/200278 [==============================] - 73s 366us/step - loss: 1.3107
#
# ------Generating with seed : " necessity. just as he cherishes the
# beautiful work of art, "
#
# ----temperature: 0.2
#  necessity. just as he cherishes the
# beautiful work of art, a
# ----temperature: 0.5
# necessity. just as he cherishes the
# beautiful work of art, an
# ----temperature: 1.0
# ecessity. just as he cherishes the
# beautiful work of art, and
# ----temperature: 1.2
# cessity. just as he cherishes the
# beautiful work of art, and epoch 29
# Epoch 1/1
# 200278/200278 [==============================] - 75s 373us/step - loss: 1.3084
#
# ------Generating with seed : "d and it can never be wholly
# learned.
#
#
# 102
#
# "=man always do"
#
# ----temperature: 0.2
# d and it can never be wholly
# learned.
#
#
# 102
#
# "=man always dom
# ----temperature: 0.5
#  and it can never be wholly
# learned.
#
#
# 102
#
# "=man always domi
# ----temperature: 1.0
# and it can never be wholly
# learned.
#
#
# 102
#
# "=man always domin
# ----temperature: 1.2
# nd it can never be wholly
# learned.
#
#
# 102
#
# "=man always domineepoch 30
# Epoch 1/1
# 200278/200278 [==============================] - 75s 373us/step - loss: 1.3065
#
# ------Generating with seed : "the
# transition from religion by way of science entails a pow"
#
# ----temperature: 0.2
# the
# transition from religion by way of science entails a powe
# ----temperature: 0.5
# he
# transition from religion by way of science entails a power
# ----temperature: 1.0
# e
# transition from religion by way of science entails a power
# ----temperature: 1.2
#
# transition from religion by way of science entails a power tepoch 31
# Epoch 1/1
# 200278/200278 [==============================] - 76s 378us/step - loss: 1.3047
#
# ------Generating with seed : "who no
# longer curses and scolds like the pessimist, the idea"
#
# ----temperature: 0.2
# who no
# longer curses and scolds like the pessimist, the idea
# ----temperature: 0.5
# ho no
# longer curses and scolds like the pessimist, the idea t
# ----temperature: 1.0
# o no
# longer curses and scolds like the pessimist, the idea th
# ----temperature: 1.2
#  no
# longer curses and scolds like the pessimist, the idea thaepoch 32
# Epoch 1/1
# 200278/200278 [==============================] - 75s 375us/step - loss: 1.3043
#
# ------Generating with seed : "lculated. thus it is, too, with human
# acts. we would be able"
#
# ----temperature: 0.2
# lculated. thus it is, too, with human
# acts. we would be able
# ----temperature: 0.5
# culated. thus it is, too, with human
# acts. we would be able t
# ----temperature: 1.0
# ulated. thus it is, too, with human
# acts. we would be able to
# ----temperature: 1.2
# lated. thus it is, too, with human
# acts. we would be able to epoch 33
# Epoch 1/1
# 200278/200278 [==============================] - 77s 384us/step - loss: 1.3011
#
# ------Generating with seed : "ession). on one occasion it
# was the specialist and the jack "
#
# ----temperature: 0.2
# ession). on one occasion it
# was the specialist and the jack a
# ----temperature: 0.5
# ssion). on one occasion it
# was the specialist and the jack at
# ----temperature: 1.0
# sion). on one occasion it
# was the specialist and the jack at
# ----temperature: 1.2
# ion). on one occasion it
# was the specialist and the jack at tepoch 34
# Epoch 1/1
# 200278/200278 [==============================] - 73s 364us/step - loss: 1.3002
#
# ------Generating with seed : "joins upon them other things, which an
# englishman can never "
#
# ----temperature: 0.2
# joins upon them other things, which an
# englishman can never b
# ----temperature: 0.5
# oins upon them other things, which an
# englishman can never be
# ----temperature: 1.0
# ins upon them other things, which an
# englishman can never bee
# ----temperature: 1.2
# ns upon them other things, which an
# englishman can never beesepoch 35
# Epoch 1/1
# 200278/200278 [==============================] - 73s 367us/step - loss: 1.2968
#
# ------Generating with seed : "e in the habit of
# placing themselves in front of life and ex"
#
# ----temperature: 0.2
# e in the habit of
# placing themselves in front of life and ext
# ----temperature: 0.5
#  in the habit of
# placing themselves in front of life and exte
# ----temperature: 1.0
# in the habit of
# placing themselves in front of life and exten
# ----temperature: 1.2
# n the habit of
# placing themselves in front of life and extentepoch 36
# Epoch 1/1
# 200278/200278 [==============================] - 74s 368us/step - loss: 1.3023
#
# ------Generating with seed : "sely in sympathy, or in acting for the good of others,
# or in"
#
# ----temperature: 0.2
# sely in sympathy, or in acting for the good of others,
# or in
# ----temperature: 0.5
# ely in sympathy, or in acting for the good of others,
# or in a
# ----temperature: 1.0
# ly in sympathy, or in acting for the good of others,
# or in an
# ----temperature: 1.2
# y in sympathy, or in acting for the good of others,
# or in an epoch 37
# Epoch 1/1
# 200278/200278 [==============================] - 73s 366us/step - loss: 1.3003
#
# ------Generating with seed : "roix, the nearest
# related to wagner; all of them great disco"
#
# ----temperature: 0.2
# roix, the nearest
# related to wagner; all of them great discov
# ----temperature: 0.5
# oix, the nearest
# related to wagner; all of them great discove
# ----temperature: 1.0
# ix, the nearest
# related to wagner; all of them great discover
# ----temperature: 1.2
# x, the nearest
# related to wagner; all of them great discover epoch 38
# Epoch 1/1
# 200278/200278 [==============================] - 74s 370us/step - loss: 1.2994
#
# ------Generating with seed : ". the distance, and as it were the space around man, grows w"
#
# ----temperature: 0.2
# . the distance, and as it were the space around man, grows wh
# ----temperature: 0.5
#  the distance, and as it were the space around man, grows whe
# ----temperature: 1.0
# the distance, and as it were the space around man, grows whet
# ----temperature: 1.2
# he distance, and as it were the space around man, grows whethepoch 39
# Epoch 1/1
# 200278/200278 [==============================] - 74s 369us/step - loss: 1.3045
#
# ------Generating with seed : " repeated proof that "instinct" is the most intelligent
# of a"
#
# ----temperature: 0.2
#  repeated proof that "instinct" is the most intelligent
# of a
# ----temperature: 0.5
# repeated proof that "instinct" is the most intelligent
# of a p
# ----temperature: 1.0
# epeated proof that "instinct" is the most intelligent
# of a pe
# ----temperature: 1.2
# peated proof that "instinct" is the most intelligent
# of a perepoch 40
# Epoch 1/1
# 200278/200278 [==============================] - 74s 367us/step - loss: 1.3044
#
# ------Generating with seed : " he unrefined and negligent perhaps he is troubled about the"
#
# ----temperature: 0.2
#  he unrefined and negligent perhaps he is troubled about the
# ----temperature: 0.5
# he unrefined and negligent perhaps he is troubled about the s
# ----temperature: 1.0
# e unrefined and negligent perhaps he is troubled about the sa
# ----temperature: 1.2
#  unrefined and negligent perhaps he is troubled about the samepoch 41
# Epoch 1/1
# 200278/200278 [==============================] - 73s 366us/step - loss: 1.2938
#
# ------Generating with seed : "e
# middle-class in its best moments--subtler even than the un"
#
# ----temperature: 0.2
# e
# middle-class in its best moments--subtler even than the unc
# ----temperature: 0.5
#
# middle-class in its best moments--subtler even than the unco
# ----temperature: 1.0
# middle-class in its best moments--subtler even than the uncon
# ----temperature: 1.2
# iddle-class in its best moments--subtler even than the unconfepoch 42
# Epoch 1/1
# 200278/200278 [==============================] - 75s 372us/step - loss: 1.2960
#
# ------Generating with seed : "ss divined what
# wisdom there is in the fact that men are sup"
#
# ----temperature: 0.2
# ss divined what
# wisdom there is in the fact that men are supp
# ----temperature: 0.5
# s divined what
# wisdom there is in the fact that men are suppo
# ----temperature: 1.0
#  divined what
# wisdom there is in the fact that men are suppos
# ----temperature: 1.2
# divined what
# wisdom there is in the fact that men are supposiepoch 43
# Epoch 1/1
# 200278/200278 [==============================] - 75s 374us/step - loss: 1.2947
#
# ------Generating with seed : "nificance of all existence, in an impending day of
# judgment."
#
# ----temperature: 0.2
# nificance of all existence, in an impending day of
# judgment.
# ----temperature: 0.5
# ificance of all existence, in an impending day of
# judgment. b
# ----temperature: 1.0
# ficance of all existence, in an impending day of
# judgment. bu
# ----temperature: 1.2
# icance of all existence, in an impending day of
# judgment. butepoch 44
# Epoch 1/1
# 200278/200278 [==============================] - 74s 371us/step - loss: 1.2854
#
# ------Generating with seed : "as outlived, they have always said "we must remove hence to
# "
#
# ----temperature: 0.2
# as outlived, they have always said "we must remove hence to
# t
# ----temperature: 0.5
# s outlived, they have always said "we must remove hence to
# th
# ----temperature: 1.0
#  outlived, they have always said "we must remove hence to
# the
# ----temperature: 1.2
# outlived, they have always said "we must remove hence to
# the epoch 45
# Epoch 1/1
# 200278/200278 [==============================] - 74s 368us/step - loss: 1.2921
#
# ------Generating with seed : "er under
# the influence of purifying knowledge. a man would l"
#
# ----temperature: 0.2
# er under
# the influence of purifying knowledge. a man would lo
# ----temperature: 0.5
# r under
# the influence of purifying knowledge. a man would loo
# ----temperature: 1.0
#  under
# the influence of purifying knowledge. a man would look
# ----temperature: 1.2
# under
# the influence of purifying knowledge. a man would look
# epoch 46
# Epoch 1/1
# 200278/200278 [==============================] - 73s 364us/step - loss: 1.3151
#
# ------Generating with seed : "d incapacity. "but why"--he said
# to himself--"should one on "
#
# ----temperature: 0.2
# d incapacity. "but why"--he said
# to himself--"should one on t
# ----temperature: 0.5
#  incapacity. "but why"--he said
# to himself--"should one on th
# ----temperature: 1.0
# incapacity. "but why"--he said
# to himself--"should one on the
# ----temperature: 1.2
# ncapacity. "but why"--he said
# to himself--"should one on the epoch 47
# Epoch 1/1
# 200278/200278 [==============================] - 73s 364us/step - loss: 1.3002
#
# ------Generating with seed : "atest and
# richest, and putting the shreds into the form of q"
#
# ----temperature: 0.2
# atest and
# richest, and putting the shreds into the form of qu
# ----temperature: 0.5
# test and
# richest, and putting the shreds into the form of que
# ----temperature: 1.0
# est and
# richest, and putting the shreds into the form of ques
# ----temperature: 1.2
# st and
# richest, and putting the shreds into the form of questepoch 48
# Epoch 1/1
# 200278/200278 [==============================] - 73s 363us/step - loss: 1.3978
#
# ------Generating with seed : "haps deserve to be laughed at when he thus
# exhorted systems "
#
# ----temperature: 0.2
# haps deserve to be laughed at when he thus
# exhorted systems o
# ----temperature: 0.5
# aps deserve to be laughed at when he thus
# exhorted systems of
# ----temperature: 1.0
# ps deserve to be laughed at when he thus
# exhorted systems of
# ----temperature: 1.2
# s deserve to be laughed at when he thus
# exhorted systems of qepoch 49
# Epoch 1/1
# 200278/200278 [==============================] - 73s 364us/step - loss: 2.2025
#
# ------Generating with seed : "stions of its origin and
# beginning: must one not be almost i"
#
# ----temperature: 0.2
# stions of its origin and
# beginning: must one not be almost iæ
# ----temperature: 0.5
# tions of its origin and
# beginning: must one not be almost iæg
# ----temperature: 1.0
# ions of its origin and
# beginning: must one not be almost iægs
# ----temperature: 1.2
# ons of its origin and
# beginning: must one not be almost iægsiepoch 50
# Epoch 1/1
#    128/200278 [..............................] - ETA: 1:16 - loss: 4.3306
# /home/ratan/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# 200278/200278 [==============================] - 74s 369us/step - loss: 6.4892
#
# ------Generating with seed : " joy of being in such a situation, and he has, perhaps,
# noth"
#
# ----temperature: 0.2
#  joy of being in such a situation, and he has, perhaps,
# nothä
# ----temperature: 0.5
# joy of being in such a situation, and he has, perhaps,
# nothää
# ----temperature: 1.0
# oy of being in such a situation, and he has, perhaps,
# nothääé
# ----temperature: 1.2
# y of being in such a situation, and he has, perhaps,
# nothääéëepoch 51
# Epoch 1/1
# 200278/200278 [==============================] - 74s 370us/step - loss: 14.9618
#
# ------Generating with seed : "n sentiments,
# that the sexual impulse sublimated into love ("
#
# ----temperature: 0.2
# n sentiments,
# that the sexual impulse sublimated into love (ä
# ----temperature: 0.5
#  sentiments,
# that the sexual impulse sublimated into love (äl
# ----temperature: 1.0
# sentiments,
# that the sexual impulse sublimated into love (älä
# ----temperature: 1.2
# entiments,
# that the sexual impulse sublimated into love (älääepoch 52
# Epoch 1/1
# 200278/200278 [==============================] - 73s 364us/step - loss: 15.6925
#
# ------Generating with seed : "ble industry and devotion.
#
#
# 56
#
# =victory of knowledge over "
#
# ----temperature: 0.2
# ble industry and devotion.
#
#
# 56
#
# =victory of knowledge over 6
# ----temperature: 0.5
# le industry and devotion.
#
#
# 56
#
# =victory of knowledge over 6
# ----temperature: 1.0
# e industry and devotion.
#
#
# 56
#
# =victory of knowledge over 6 ä
# ----temperature: 1.2
#  industry and devotion.
#
#
# 56
#
# =victory of knowledge over 6 äuepoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 73s 363us/step - loss: 15.9071
#
# ------Generating with seed : "logician, will be illuminated with a new
# light: "the univers"
#
# ----temperature: 0.2
# logician, will be illuminated with a new
# light: "the universä
# ----temperature: 0.5
# ogician, will be illuminated with a new
# light: "the universää
# ----temperature: 1.0
# gician, will be illuminated with a new
# light: "the universääi
# ----temperature: 1.2
# ician, will be illuminated with a new
# light: "the universääiäepoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 73s 364us/step - loss: 12.7363
#
# ------Generating with seed : "f this pudendum: the latter may, consequently, be prompt to
# "
#
# ----temperature: 0.2
# f this pudendum: the latter may, consequently, be prompt to
#
# ----temperature: 0.5
#  this pudendum: the latter may, consequently, be prompt to
#  o
# ----temperature: 1.0
# this pudendum: the latter may, consequently, be prompt to
#  oi
# ----temperature: 1.2
# his pudendum: the latter may, consequently, be prompt to
#  oitepoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 75s 372us/step - loss: 9.4101
#
# ------Generating with seed : "make abundant concessions to the democratic instincts of the"
#
# ----temperature: 0.2
# make abundant concessions to the democratic instincts of thes
# ----temperature: 0.5
# ake abundant concessions to the democratic instincts of thes
# ----temperature: 1.0
# ke abundant concessions to the democratic instincts of thes t
# ----temperature: 1.2
# e abundant concessions to the democratic instincts of thes t2epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 74s 368us/step - loss: 7.4892
#
# ------Generating with seed : " read for the
# ear, but only with his eyes; he has put his ea"
#
# ----temperature: 0.2
#  read for the
# ear, but only with his eyes; he has put his ea
# ----temperature: 0.5
# read for the
# ear, but only with his eyes; he has put his ea s
# ----temperature: 1.0
# ead for the
# ear, but only with his eyes; he has put his ea sa
# ----temperature: 1.2
# ad for the
# ear, but only with his eyes; he has put his ea satepoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 73s 367us/step - loss: 7.0234
#
# ------Generating with seed : "
# affinity of language, owing to the common philosophy of gra"
#
# ----temperature: 0.2
#
# affinity of language, owing to the common philosophy of grai
# ----temperature: 0.5
# affinity of language, owing to the common philosophy of graiq
# ----temperature: 1.0
# ffinity of language, owing to the common philosophy of graiqa
# ----temperature: 1.2
# finity of language, owing to the common philosophy of graiqaeepoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 74s 372us/step - loss: 6.9152
#
# ------Generating with seed : "version of valuations (in which is also included
# the use of "
#
# ----temperature: 0.2
# version of valuations (in which is also included
# the use of r
# ----temperature: 0.5
# ersion of valuations (in which is also included
# the use of ri
# ----temperature: 1.0
# rsion of valuations (in which is also included
# the use of rin
# ----temperature: 1.2
# sion of valuations (in which is also included
# the use of rin epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 73s 366us/step - loss: 6.6531
#
# ------Generating with seed : " could be arrived at, or even pronounced out of
# the question"
#
# ----temperature: 0.2
#  could be arrived at, or even pronounced out of
# the questione
# ----temperature: 0.5
# could be arrived at, or even pronounced out of
# the questione
# ----temperature: 1.0
# ould be arrived at, or even pronounced out of
# the questione n
# ----temperature: 1.2
# uld be arrived at, or even pronounced out of
# the questione nr
