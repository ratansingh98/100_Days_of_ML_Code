# %%
# Necessary imports
from __future__ import print_function
import time
from PIL import Image
import numpy as np

from keras import backend
from keras.models import Model
from keras.applications.vgg16 import VGG16

from scipy.optimize import fmin_l_bfgs_b
from scipy.misc import imsave
# Out:
# Using TensorFlow backend.

# %%
# Load image after resize
height = 512
width = 512

content_image_path = 'images/cutie.jpeg'
content_image = Image.open(content_image_path)
content_image = content_image.resize((height, width))
content_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F3005192550>

# %%
# Load style
style_image_path = 'style/paint1.jpg'
style_image = Image.open(style_image_path)
style_image = style_image.resize((height, width))
style_image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F300512FB70>

# %%
# Check the dimensions of images
content_array = np.asarray(content_image, dtype='float32')
content_array = np.expand_dims(content_array, axis=0)
print(content_array.shape)

style_array = np.asarray(style_image, dtype='float32')
style_array = np.expand_dims(style_array, axis=0)
print(style_array.shape)
# Out:
# (1, 512, 512, 3)
# (1, 512, 512, 3)

# %%
# Flipt the dimensions from RGB to BGR
content_array[:, :, :, 0] -= 103.939
content_array[:, :, :, 1] -= 116.779
content_array[:, :, :, 2] -= 123.68
content_array = content_array[:, :, :, ::-1]

style_array[:, :, :, 0] -= 103.939
style_array[:, :, :, 1] -= 116.779
style_array[:, :, :, 2] -= 123.68
style_array = style_array[:, :, :, ::-1]

# %%
# Placeholder for processed image 
content_image = backend.variable(content_array)
style_image = backend.variable(style_array)
combination_image = backend.placeholder((1, height, width, 3))

# %%
# Concatenate image
input_tensor = backend.concatenate([content_image,
                                    style_image,
                                    combination_image], axis=0)

# %%
# Create model for VGG16
model = VGG16(input_tensor=input_tensor, weights='imagenet',
              include_top=False)

# %%
# Check the layer
layers = dict([(layer.name, layer.output) for layer in model.layers])
layers
# Out:
# {'input_1': <tf.Tensor 'concat:0' shape=(3, 512, 512, 3) dtype=float32>,
#  'block1_conv1': <tf.Tensor 'block1_conv1/Relu:0' shape=(3, 512, 512, 64) dtype=float32>,
#  'block1_conv2': <tf.Tensor 'block1_conv2/Relu:0' shape=(3, 512, 512, 64) dtype=float32>,
#  'block1_pool': <tf.Tensor 'block1_pool/MaxPool:0' shape=(3, 256, 256, 64) dtype=float32>,
#  'block2_conv1': <tf.Tensor 'block2_conv1/Relu:0' shape=(3, 256, 256, 128) dtype=float32>,
#  'block2_conv2': <tf.Tensor 'block2_conv2/Relu:0' shape=(3, 256, 256, 128) dtype=float32>,
#  'block2_pool': <tf.Tensor 'block2_pool/MaxPool:0' shape=(3, 128, 128, 128) dtype=float32>,
#  'block3_conv1': <tf.Tensor 'block3_conv1/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_conv2': <tf.Tensor 'block3_conv2/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_conv3': <tf.Tensor 'block3_conv3/Relu:0' shape=(3, 128, 128, 256) dtype=float32>,
#  'block3_pool': <tf.Tensor 'block3_pool/MaxPool:0' shape=(3, 64, 64, 256) dtype=float32>,
#  'block4_conv1': <tf.Tensor 'block4_conv1/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_conv2': <tf.Tensor 'block4_conv2/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_conv3': <tf.Tensor 'block4_conv3/Relu:0' shape=(3, 64, 64, 512) dtype=float32>,
#  'block4_pool': <tf.Tensor 'block4_pool/MaxPool:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv1': <tf.Tensor 'block5_conv1/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv2': <tf.Tensor 'block5_conv2/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_conv3': <tf.Tensor 'block5_conv3/Relu:0' shape=(3, 32, 32, 512) dtype=float32>,
#  'block5_pool': <tf.Tensor 'block5_pool/MaxPool:0' shape=(3, 16, 16, 512) dtype=float32>}

# %%
content_weight = 0.025
style_weight = 5.0
total_variation_weight = 1.0

# %%
# Define loss
loss = backend.variable(0.)

# %%
def content_loss(content, combination):
    return backend.sum(backend.square(combination - content))

layer_features = layers['block2_conv2']
content_image_features = layer_features[0, :, :, :]
combination_features = layer_features[2, :, :, :]

loss += content_weight * content_loss(content_image_features,
                                      combination_features)
# Out:
# WARNING:tensorflow:Variable += will be deprecated. Use variable.assign_add if you want assignment to the variable value or 'x = x + y' if you want a new python Tensor object.

# %%
def gram_matrix(x):
    features = backend.batch_flatten(backend.permute_dimensions(x, (2, 0, 1)))
    gram = backend.dot(features, backend.transpose(features))
    return gram

# %%
def style_loss(style, combination):
    S = gram_matrix(style)
    C = gram_matrix(combination)
    channels = 3
    size = height * width
    return backend.sum(backend.square(S - C)) / (4. * (channels ** 2) * (size ** 2))

feature_layers = ['block1_conv2', 'block2_conv2',
                  'block3_conv3', 'block4_conv3',
                  'block5_conv1']
for layer_name in feature_layers:
    layer_features = layers[layer_name]
    style_features = layer_features[1, :, :, :]
    combination_features = layer_features[2, :, :, :]
    sl = style_loss(style_features, combination_features)
    loss += (style_weight / len(feature_layers)) * sl

# %%
def total_variation_loss(x):
    a = backend.square(x[:, :height-1, :width-1, :] - x[:, 1:, :width-1, :])
    b = backend.square(x[:, :height-1, :width-1, :] - x[:, :height-1, 1:, :])
    return backend.sum(backend.pow(a + b, 1.25))

loss += total_variation_weight * total_variation_loss(combination_image)

# %%
# Gradients
grads = backend.gradients(loss, combination_image)

# %%
outputs = [loss]
outputs += grads
f_outputs = backend.function([combination_image], outputs)

def eval_loss_and_grads(x):
    x = x.reshape((1, height, width, 3))
    outs = f_outputs([x])
    loss_value = outs[0]
    grad_values = outs[1].flatten().astype('float64
# Current loss value: 16224463000.0
# Iteration 36 completed in 5s
# Start of iteration 37
# Current loss value: 16222583000.0
# Iteration 37 completed in 5s
# Start of iteration 38
# Current loss value: 16220938000.0
# Iteration 38 completed in 5s
# Start of iteration 39
# Current loss value: 16219493000.0
# Iteration 39 completed in 5s
# Start of iteration 40
# Current loss value: 16218226000.0
# Iteration 40 completed in 5s
# Start of iteration 41
# Current loss value: 16217104000.0
# Iteration 41 completed in 5s
# Start of iteration 42
# Current loss value: 16216080000.0
# Iteration 42 completed in 5s
# Start of iteration 43
# Current loss value: 16215176000.0
# Iteration 43 completed in 5s
# Start of iteration 44
# Current loss value: 16214345000.0
# Iteration 44 completed in 5s
# Start of iteration 45
# Current loss value: 16213562000.0
# Iteration 45 completed in 5s
# Start of iteration 46
# Current loss value: 16212835000.0
# Iteration 46 completed in 5s
# Start of iteration 47
# Current loss value: 16212169000.0
# Iteration 47 completed in 5s
# Start of iteration 48
# Current loss value: 16211558000.0
# Iteration 48 completed in 5s
# Start of iteration 49
# Current loss value: 16211019000.0
# Iteration 49 completed in 5s
# Start of iteration 50
# Current loss value: 16210506000.0
# Iteration 50 completed in 5s
# Start of iteration 51
# Current loss value: 16210011000.0
# Iteration 51 completed in 5s
# Start of iteration 52
# Current loss value: 16209547000.0
# Iteration 52 completed in 5s
# Start of iteration 53
# Current loss value: 16209109000.0
# Iteration 53 completed in 5s
# Start of iteration 54
# Current loss value: 16208659000.0
# Iteration 54 completed in 5s
# Start of iteration 55
# Current loss value: 16208200000.0
# Iteration 55 completed in 5s
# Start of iteration 56
# Current loss value: 16207757000.0
# Iteration 56 completed in 5s
# Start of iteration 57
# Current loss value: 16207348000.0
# Iteration 57 completed in 5s
# Start of iteration 58
# Current loss value: 16206962000.0
# Iteration 58 completed in 5s
# Start of iteration 59
# Current loss value: 16206585000.0
# Iteration 59 completed in 5s
# Start of iteration 60
# Current loss value: 16206222000.0
# Iteration 60 completed in 5s
# Start of iteration 61
# Current loss value: 16205862000.0
# Iteration 61 completed in 5s
# Start of iteration 62
# Current loss value: 16205497000.0
# Iteration 62 completed in 5s
# Start of iteration 63
# Current loss value: 16205165000.0
# Iteration 63 completed in 5s
# Start of iteration 64
# Current loss value: 16204860000.0
# Iteration 64 completed in 5s
# Start of iteration 65
# Current loss value: 16204560000.0
# Iteration 65 completed in 5s
# Start of iteration 66
# Current loss value: 16204249000.0
# Iteration 66 completed in 5s
# Start of iteration 67
# Current loss value: 16203944000.0
# Iteration 67 completed in 5s
# Start of iteration 68
# Current loss value: 16203671000.0
# Iteration 68 completed in 5s
# Start of iteration 69
# Current loss value: 16203391000.0
# Iteration 69 completed in 5s

# %%
# View image
x = x.reshape((height, width, 3))
x = x[:, :, ::-1]
x[:, :, 0] += 103.939
x[:, :, 1] += 116.779
x[:, :, 2] += 123.68
x = np.clip(x, 0, 255).astype('uint8')

# %%
res = Image.fromarray(x)

# %%
res.save('result.jpg')

# %%
res
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7F2FFFB95C50>
